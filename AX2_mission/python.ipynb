# %% [markdown]
# part 1

# %%
scores = [85, 92, 78, 96, 88]
count = 0
for score in scores:
    if score >= 80:
        print(score)
        count += 1
print(f"80점 이상 {count}명")
# Out:
# 85
# 92
# 96
# 88
# 80점 이상 4명

# %% [markdown]
# part 2

# %%
sentence = "파이썬 공부는 재미있다 파이썬 공부는 어렵지만 재미있다 데이터 분석에도 파이썬을 사용한다 파이썬 공부를 계속하면 실력이 늘어난다"
words = sentence.split()
freq = {}
for word in words:
    if word in freq:
        freq[word] += 1
    else:
        freq[word] = 1

for word, count in freq.items():
    print(f"{word}: {count}회")

min_count = 2

for word, count in freq.items():
    if count >= min_count:
        print(f"{word}: {count}회")
# Out:
# 파이썬: 3회
# 공부는: 2회
# 재미있다: 2회
# 어렵지만: 1회
# 데이터: 1회
# 분석에도: 1회
# 파이썬을: 1회
# 사용한다: 1회
# 공부를: 1회
# 계속하면: 1회
# 실력이: 1회
# 늘어난다: 1회
# 파이썬: 3회
# 공부는: 2회
# 재미있다: 2회

# %% [markdown]
# part 3

# %%
def count_words(sentence):
    words = sentence.split()
    freq = {}
    for word in words:
        if word in freq:
            freq[word] += 1
        else:
            freq[word] = 1
    return freq

def filter_words(freq, min_count):
    result ={}
    for word, count in freq.items():
        if count >= min_count:
            result[word] = count
    return result

freq = count_words(sentence)
print(freq)

top_words = filter_words(freq, 2)
print(top_words)
# Out:
# {'파이썬': 3, '공부는': 2, '재미있다': 2, '어렵지만': 1, '데이터': 1, '분석에도': 1, '파이썬을': 1, '사용한다': 1, '공부를': 1, '계속하면': 1, '실력이': 1, '늘어난다': 1}
# {'파이썬': 3, '공부는': 2, '재미있다': 2}

# %% [markdown]
# part 4

# %%
def count_words(sentence):       
    words = sentence.split()
    freq = {}
    for word in words:
        if word in freq:
            freq[word] += 1
        else:
            freq[word] = 1
    return freq

try:
    result = count_words(123)     
    print(result)
except AttributeError:                   
    print("문자열이 아닙니다. 문자열을 입력해주세요.")
# Out:
# 문자열이 아닙니다. 문자열을 입력해주세요.

# %% [markdown]
# 확인 질문
#
# 1. for 반복문은 이 프로그램에서 어떤 역할을 하나요?
# - 함수 안 값을 반복해서 불러오는 역할
# 2. 딕셔너리의 Key와 Value에는 각각 무엇이 저장되나요?
# - 값과 그 데이터
# 3. 같은 단어가 다시 등장하면 딕셔너리 값은 어떻게 달라지나요?
# - 새로운 값으로 덮어씌워짐
# 4. 함수를 사용하는 이유는 무엇인가요?
# - 재사용하기 위함
# 5. AI를 사용했다면 AI가 제안한 코드에서 직접 확인하거나 수정한 부분은 무엇인가요?
# -  AI에게 모든 코드를 요구하지 않고 코드에 빈칸을 만들고 힌트를 받으며 작성
